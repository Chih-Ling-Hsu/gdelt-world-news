# %%
import pandas as pd

# %%
df = pd.read_csv('world_population.tsv', sep='	')

# %%
df.to_json()
# Out:
# '{"ID":{"0":"CHN","1":"IND","2":"USA","3":"IDN","4":"BRA","5":"PAK","6":"BGD","7":"NGA","8":"RUS","9":"JPN","10":"MEX","11":"PHL","12":"VNM","13":"ETH","14":"DEU","15":"EGY","16":"TUR","17":"COD","18":"IRN","19":"THA","20":"FRA","21":"GBR","22":"ITA","23":"MMR","24":"ZAF","25":"KOR","26":"UKR","27":"COL","28":"SDN","29":"TZA","30":"ARG","31":"ESP","32":"KEN","33":"POL","34":"DZA","35":"CAN","36":"UGA","37":"MAR","38":"PER","39":"IRQ","40":"SAU","41":"AFG","42":"NPL","43":"UZB","44":"VEN","45":"MYS","46":"GHA","47":"YEM","48":"TWN","49":"PRK","50":"SYR","51":"ROU","52":"MOZ","53":"AUS","54":"LKA","55":"MDG","56":"CIV","57":"CMR","58":"NLD","59":"CHL","60":"BFA","61":"NER","62":"KAZ","63":"MWI","64":"ECU","65":"KHM","66":"SEN","67":"MLI","68":"GTM","69":"AGO","70":"ZMB","71":"ZWE","72":"CUB","73":"RWA","74":"GRC","75":"PRT","76":"TUN","77":"TCD","78":"BEL","79":"GIN","80":"CZE","81":"SOM","82":"BOL","83":"HUN","84":"BDI","85":"DOM","86":"BLR","87":"HTI","88":"SWE","89":"BEN","90":"AZE"
# ...
